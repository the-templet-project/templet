// %%
#include "dbase.hpp"

// %%
templet::memwal wal;
user_full_name ufname(wal);

// %%
templet::filewal wal("dbase.txt");
user_full_name ufname(wal);

// %%
std::cout << "Please, enter user name:" << std::endl;
std::string user_name;
getline(std::cin,user_name);
std::cout << "Please, enter full name:" << std::endl;
std::string full_name;
getline(std::cin,full_name);
ufname.change_full_name(user_name,full_name);

// %%
ufname.print(std::cout);

// %%
wal.print();
