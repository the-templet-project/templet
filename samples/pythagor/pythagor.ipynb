// %% [raw]
// process #pragma templet ...  in 'pythagor.cpp' file (reload the file after processing, if needed)

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    bool op1 = (system("~/bin/cgen pythagor.cpp pythagor.cgen.cpp > out1.txt")==0);
    system("cp pythagor.cpp pythagor.bak");
    bool op2 = op1 ? (system("~/bin/skel -i pythagor.cpp -s pythagor.cgen.cpp > out2.txt")==0):false;
    if(op2) cout << "preprocessing is Ok:\n\n"; else  cout << "preprocessing failed:\n\n"; 
    {ifstream file("out1.txt"); for (string line; getline(file, line); ){cout << line << endl;} }
    if(op1){cout << endl; ifstream file("out2.txt"); for (string line; getline(file, line); ){cout << line << endl;} }
    system("rm out1.txt"); system("rm out2.txt"); system("rm pythagor.cgen.cpp");
}

// %% [raw]
// compile 'pythagor.cpp' file

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    system("g++ pythagor.cpp -fpermissive -l curl -I ~/lib -o pythagor 2> out.txt");
    ifstream file("out.txt"); bool ok=true; for (string line; getline(file, line); ){cout << line << endl; ok = false;}
    if(ok)cout << "Compilation is Ok";
    system("rm out.txt");
}

// %% [raw]
// run pythagor sample

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    system("./pythagor > out.txt");
    ifstream file("out.txt"); bool ok=true; for (string line; getline(file, line); ){cout << line << endl; ok = false;}
    system("rm out.txt");
}
