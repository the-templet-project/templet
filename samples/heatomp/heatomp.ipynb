// %% [raw]
// process #pragma templet ...  in 'heatomp.cpp' file (reload the file after processing, if needed)

// %%
#include <cstdlib>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    system("~/bin/acta heatomp.cpp > out.txt");
    ifstream file("out.txt"); for (string line; getline(file, line); )cout << line << endl;
    system("rm out.txt");
}

// %% [raw]
// compile 'heatomp.cpp' file

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    system("g++ heatomp.cpp -fopenmp -O2 -I ~/lib -o heatomp 2> out.txt");
    ifstream file("out.txt"); bool ok=true; for (string line; getline(file, line); ){cout << line << endl; ok = false;}
    if(ok)cout << "Compilation is Ok";
    system("rm out.txt");
}

// %% [raw]
// run heatomp sample

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    system("./heatomp > out.txt");
    ifstream file("out.txt"); bool ok=true; for (string line; getline(file, line); ){cout << line << endl; ok = false;}
    system("rm out.txt");
}
// Out:
// Maximum number of tasks executed in parallel : 8
// Time of sequential execution of all tasks    : 6.49759
// Time of parallel   execution of all tasks    : 65.1744
// Speed-up                                     : 0.0996954
