// %% [raw]
// process #pragma templet ...  in 'heatomp.cpp' file (reload the file after processing, if needed)

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    bool op1 = (system("~/bin/cgen heatomp.cpp heatomp.cgen.cpp > out1.txt")==0);
    system("cp heatomp.cpp heatomp.bak");
    bool op2 = op1 ? (system("~/bin/skel -i heatomp.cpp -s heatomp.cgen.cpp > out2.txt")==0):false;
    if(op2) cout << "preprocessing is Ok:\n\n"; else  cout << "preprocessing failed:\n\n"; 
    {ifstream file("out1.txt"); for (string line; getline(file, line); ){cout << line << endl;} }
    if(op1){cout << endl; ifstream file("out2.txt"); for (string line; getline(file, line); ){cout << line << endl;} }
    system("rm out1.txt"); system("rm out2.txt"); system("rm heatomp.cgen.cpp");
}

// %% [raw]
// compile 'heatomp.cpp' file

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    system("g++ heatomp.cpp -I ~/lib -o heatomp 2> out.txt");
    ifstream file("out.txt"); bool ok=true; for (string line; getline(file, line); ){cout << line << endl; ok = false;}
    if(ok)cout << "Compilation is Ok";
    system("rm out.txt");
}

// %% [raw]
// run heatomp sample

// %%
#include <stdlib.h>
#include <iostream>
#include <fstream>
#include <string>
using namespace std;
{
    system("./heatomp > out.txt");
    ifstream file("out.txt"); bool ok=true; for (string line; getline(file, line); ){cout << line << endl; ok = false;}
    system("rm out.txt");
}
