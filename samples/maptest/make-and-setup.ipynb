// %%
!g++ echonum.cpp -o echonum

// %%
!./echonum

// %%
!rm file*

// %%
!g++ state-sync-test.cpp -I ../../lib -o state-sync-test

// %%
!./state-sync-test

// %%
!g++ everest-test.cpp -I ../../lib -l curl -o everest-test
// Out:
// ERROR: received unknown message
// Message type: usage_request

// %%
!./everest-test 3
// Out:
// submit task from = 0 to = 3 size = 10
// submit task from = 4 to = 6 size = 10
// submit task from = 7 to = 9 size = 10
// 0^2 = 0
// 1^2 = 0
// 2^2 = 0
// 3^2 = 0
// 4^2 = 0
// 5^2 = 0
// 6^2 = 0
// 7^2 = 0
// 8^2 = 0
// 9^2 = 0
// Execution time (in sec): 0.00011727
// ERROR: received unknown message
// Message type: usage_request
