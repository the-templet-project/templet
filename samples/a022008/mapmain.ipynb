// %%
#include "mapmain.hpp"

// %%
{   
    const int  NUMBER_OF_TASK_SLOTS    = 5;
    const long long SEARCH_RANGE_LIMIT = 19634100;//#30
    
    bool master = true;
    
    base_engine eng;
    sextuples_mapper a_mapper(eng,NUMBER_OF_TASK_SLOTS,SEARCH_RANGE_LIMIT);
    
    if(master){
        a_mapper.init(NUMBER_OF_TASK_SLOTS);
    }
    
    a_mapper.map();
   
    if(master){
        int i = 0;
        for(auto& it1:a_mapper.primesixs)for(auto& it2:it1)
            std::cout<< "a022008(" << ++i << ") = " << it2 << std::endl;         
        std::cout << "duration = " << eng.duration() << " s" << std::endl;
    }
}
// Out:
// a022008() = 7
// a022008() = 97
// a022008() = 16057
// a022008() = 19417
// a022008() = 43777
// a022008() = 1091257
// a022008() = 1615837
// a022008() = 1954357
// a022008() = 2822707
// a022008() = 2839927
// a022008() = 3243337
// a022008() = 3400207
// a022008() = 6005887
// a022008() = 6503587
// a022008() = 7187767
// a022008() = 7641367
// a022008() = 8061997
// a022008() = 8741137
// a022008() = 10526557
// a022008() = 11086837
// a022008() = 11664547
// a022008() = 14520547
// a022008() = 14812867
// a022008() = 14834707
// a022008() = 14856757
// a022008() = 16025827
// a022008() = 16094707
// a022008() = 18916477
// a022008() = 19197247
// a022008() = 19634047
// a022008(1) = 7
// a022008(2) = 97
// a022008(3) = 16057
// a022008(4) = 19417
// a022008(5) = 43777
// a022008(6) = 1091257
// a022008(7) = 1615837
// a022008(8) = 1954357
// a022008(9) = 2822707
// a022008(10) = 2839927
// a022008(11) = 3243337
// a022008(12) = 3400207
// a022008(13) = 6005887
// ...
